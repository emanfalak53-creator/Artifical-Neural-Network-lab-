# %% [markdown]
# <a href="https://colab.research.google.com/github/emanfalak53-creator/Artifical-Neural-Network-lab-/blob/main/NLP_LAB_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Task 01: Strings as Text Storage

# Part (a)
sentence = "Artificial Intelligence is transforming Natural Language Processing"

print("----- Part (a) -----")
print("Sentence:", sentence)
print("Data type:", type(sentence))
print("Number of characters:", len(sentence))


# Part (b)
print("\n----- Part (b) -----")

first_word = sentence[:10]
last_character = sentence[-1]
language_word = sentence[48:56]

print("First word:", first_word)
print("Last character:", last_character)
print("Word 'Language':", language_word)


# Part (c)
print("\n----- Part (c) -----")

exists = "Intelligence" in sentence
position = sentence.find("Intelligence")

print("Does 'Intelligence' exist?", exists)
print("Starting index:", position)


# Part (d)
print("\n----- Part (d) -----")

paragraph = """Natural Language Processing helps computers understand human language.
NLP is widely used in chatbots and translation systems.
Machine learning makes NLP applications more powerful."""

sentences = paragraph.split("\n")

for sentence in sentences:
    print(sentence)
# Out:
# ----- Part (a) -----
# Sentence: Artificial Intelligence is transforming Natural Language Processing
# Data type: <class 'str'>
# Number of characters: 67
#
# ----- Part (b) -----
# First word: Artificial
# Last character: g
# Word 'Language': Language
#
# ----- Part (c) -----
# Does 'Intelligence' exist? True
# Starting index: 11
#
# ----- Part (d) -----
# Natural Language Processing helps computers understand human language.
# NLP is widely used in chatbots and translation systems.
# Machine learning makes NLP applications more powerful.

# %%
# Task 02: Lists for Token Management

# Part (a)
tokens = ["deep", "learning", "helps", "machines", "understand", "text"]

print("----- Part (a) -----")
print("Full list:", tokens)
print("Length:", len(tokens))
print("Element at index 2:", tokens[2])
print("Last element:", tokens[-1])


# Part (b)
print("\n----- Part (b) -----")

tokens.append("efficiently")
print("After append:", tokens)

tokens.insert(3, "computers")
print("After insert:", tokens)

tokens.remove("helps")
print("After remove:", tokens)


# Part (c)
print("\n----- Part (c) -----")

tokens_A = ["NLP", "uses", "Python"]
tokens_B = ["for", "text", "analysis"]

full_tokens = tokens_A + tokens_B

print("Combined list:", full_tokens)
print("Last three elements:", full_tokens[-3:])


# Part (d)
print("\n----- Part (d) -----")

sorted_tokens = sorted(full_tokens)
length_sorted = sorted(full_tokens, key=len)

print("Alphabetically sorted:", sorted_tokens)
print("Sorted by word length:", length_sorted)
# Out:
# ----- Part (a) -----
# Full list: ['deep', 'learning', 'helps', 'machines', 'understand', 'text']
# Length: 6
# Element at index 2: helps
# Last element: text
#
# ----- Part (b) -----
# After append: ['deep', 'learning', 'helps', 'machines', 'understand', 'text', 'efficiently']
# After insert: ['deep', 'learning', 'helps', 'computers', 'machines', 'understand', 'text', 'efficiently']
# After remove: ['deep', 'learning', 'computers', 'machines', 'understand', 'text', 'efficiently']
#
# ----- Part (c) -----
# Combined list: ['NLP', 'uses', 'Python', 'for', 'text', 'analysis']
# Last three elements: ['for', 'text', 'analysis']
#
# ----- Part (d) -----
# Alphabetically sorted: ['NLP', 'Python', 'analysis', 'for', 'text', 'uses']
# Sorted by word length: ['NLP', 'for', 'uses', 'text', 'Python', 'analysis']

# %%
# Task 03: Dictionaries for Word Mapping

# Part (a)
print("----- Part (a) -----")

word_freq = {
    "machine": 4,
    "learning": 7,
    "data": 5,
    "model": 3,
    "text": 6
}

print("Word frequencies:", word_freq)
print("Frequency of learning:", word_freq["learning"])

word_freq["data"] = 9

print("Updated dictionary:", word_freq)


# Part (b)
print("\n----- Part (b) -----")

word_freq["neural"] = 8
word_freq["network"] = 5

del word_freq["model"]

if "text" in word_freq:
    print("The word 'text' exists in the dictionary.")
else:
    print("The word 'text' does not exist in the dictionary.")

print("Final dictionary:", word_freq)


# Part (c)
print("\n----- Part (c) -----")

vocab = {
    "nlp": 0,
    "python": 1,
    "token": 2,
    "vector": 3,
    "corpus": 4
}

id_to_word = {}

for word, word_id in vocab.items():
    id_to_word[word_id] = word

print("Word to ID:", vocab)
print("ID to Word:", id_to_word)


# Part (d)
print("\n----- Part (d) -----")

for word, frequency in word_freq.items():
    print(f'Word: "{word}" → Frequency: {frequency}')

print("Total number of unique words:", len(word_freq))
# Out:
# ----- Part (a) -----
# Word frequencies: {'machine': 4, 'learning': 7, 'data': 5, 'model': 3, 'text': 6}
# Frequency of learning: 7
# Updated dictionary: {'machine': 4, 'learning': 7, 'data': 9, 'model': 3, 'text': 6}
#
# ----- Part (b) -----
# The word 'text' exists in the dictionary.
# Final dictionary: {'machine': 4, 'learning': 7, 'data': 9, 'text': 6, 'neural': 8, 'network': 5}
#
# ----- Part (c) -----
# Word to ID: {'nlp': 0, 'python': 1, 'token': 2, 'vector': 3, 'corpus': 4}
# ID to Word: {0: 'nlp', 1: 'python', 2: 'token', 3: 'vector', 4: 'corpus'}
#
# ----- Part (d) -----
# Word: "machine" → Frequency: 4
# Word: "learning" → Frequency: 7
# Word: "data" → Frequency: 9
# Word: "text" → Frequency: 6
# Word: "neural" → Frequency: 8
# Word: "network" → Frequency: 5
# Total number of unique words: 6

# %%
# Task 04: Sets for Unique Vocabulary


# Part (a)
print("----- Part (a) -----")

raw = ["nlp", "ai", "nlp", "deep", "learning", "ai", "nlp", "python"]

vocab = set(raw)

print("Raw list:", raw)
print("Vocabulary set:", vocab)
print("Number of unique words:", len(vocab))



# Part (b)
print("\n----- Part (b) -----")

set_A = {"machine", "learning", "data", "model"}
set_B = {"deep", "learning", "neural", "data"}

union_set = set_A | set_B
intersection_set = set_A & set_B
difference_set = set_A - set_B

print("Union:", union_set)
print("Intersection:", intersection_set)
print("Difference (A - B):", difference_set)


# Part (c)
print("\n----- Part (c) -----")

stopwords = {"is", "the", "a", "in", "of", "and", "to"}

tokens = ["nlp", "is", "a", "field", "of", "ai", "and", "the", "future"]

cleaned_tokens = set(tokens) - stopwords

print("Original tokens:", tokens)
print("Cleaned tokens:", cleaned_tokens)


# Part (d)
print("\n----- Part (d) -----")

vocab.add("transformer")
vocab.add("bert")

vocab.discard("python")

if "ai" in vocab:
    print("'ai' is still present in the vocabulary.")
else:
    print("'ai' is not present in the vocabulary.")

print("Final vocabulary:", vocab)
# Out:
# ----- Part (a) -----
# Raw list: ['nlp', 'ai', 'nlp', 'deep', 'learning', 'ai', 'nlp', 'python']
# Vocabulary set: {'deep', 'python', 'nlp', 'learning', 'ai'}
# Number of unique words: 5
#
# ----- Part (b) -----
# Union: {'deep', 'data', 'neural', 'learning', 'model', 'machine'}
# Intersection: {'data', 'learning'}
# Difference (A - B): {'machine', 'model'}
#
# ----- Part (c) -----
# Original tokens: ['nlp', 'is', 'a', 'field', 'of', 'ai', 'and', 'the', 'future']
# Cleaned tokens: {'future', 'ai', 'field', 'nlp'}
#
# ----- Part (d) -----
# 'ai' is still present in the vocabulary.
# Final vocabulary: {'deep', 'transformer', 'nlp', 'learning', 'bert', 'ai'}

# %%
# Task 05: Tuples for Fixed Linguistic Data


# Part (a)
print("----- Part (a) -----")

pos_tags = [
    ("language", "NOUN"),
    ("processes", "VERB"),
    ("human", "ADJ"),
    ("text", "NOUN"),
    ("quickly", "ADV")
]

print("POS tags:", pos_tags)

print("Word from second tuple:", pos_tags[1][0])
print("Tag from second tuple:", pos_tags[1][1])


# Part (b)
print("\n----- Part (b) -----")

word, tag = pos_tags[0]

print("Word:", word)
print("Tag:", tag)

try:
    pos_tags[0][1] = "VERB"
except TypeError as e:
    print("Error:", e)


# Part (c)
print("\n----- Part (c) -----")

def extract_nouns(pos_list):
    nouns = []

    for word, tag in pos_list:
        if tag == "NOUN":
            nouns.append(word)

    return nouns


nouns = extract_nouns(pos_tags)

print("Nouns:", nouns)


# Part (d)
print("\n----- Part (d) -----")

pipeline_steps = (
    "load_data",
    "clean_text",
    "tokenize",
    "remove_stopwords",
    "vectorize"
)

print("Pipeline:", pipeline_steps)

tokenize_position = pipeline_steps.index("tokenize")

print("Position of 'tokenize':", tokenize_position)
print("Total number of steps:", len(pipeline_steps))

try:
    del pipeline_steps[0]
except TypeError as e:
    print("Error:", e)
# Out:
# ----- Part (a) -----
# POS tags: [('language', 'NOUN'), ('processes', 'VERB'), ('human', 'ADJ'), ('text', 'NOUN'), ('quickly', 'ADV')]
# Word from second tuple: processes
# Tag from second tuple: VERB
#
# ----- Part (b) -----
# Word: language
# Tag: NOUN
# Error: 'tuple' object does not support item assignment
#
# ----- Part (c) -----
# Nouns: ['language', 'text']
#
# ----- Part (d) -----
# Pipeline: ('load_data', 'clean_text', 'tokenize', 'remove_stopwords', 'vectorize')
# Position of 'tokenize': 2
# Total number of steps: 5
# Error: 'tuple' object doesn't support item deletion

# %%
# Task 05: Tuples for Fixed Linguistic Data


# Part (a)
print("----- Part (a) -----")

pos_tags = [
    ("language", "NOUN"),
    ("processes", "VERB"),
    ("human", "ADJ"),
    ("text", "NOUN"),
    ("quickly", "ADV")
]

print("POS tags:", pos_tags)

print("Word from second tuple:", pos_tags[1][0])
print("Tag from second tuple:", pos_tags[1][1])


# Part (b)
print("\n----- Part (b) -----")

word, tag = pos_tags[0]

print("Word:", word)
print("Tag:", tag)

try:
    pos_tags[0][1] = "VERB"
except TypeError as e:
    print("Error:", e)


# Part (c)
print("\n----- Part (c) -----")

def extract_nouns(pos_list):
    nouns = []

    for word, tag in pos_list:
        if tag == "NOUN":
            nouns.append(word)

    return nouns


nouns = extract_nouns(pos_tags)

print("Nouns:", nouns)


# Part (d)
print("\n----- Part (d) -----")

pipeline_steps = (
    "load_data",
    "clean_text",
    "tokenize",
    "remove_stopwords",
    "vectorize"
)

print("Pipeline:", pipeline_steps)

tokenize_position = pipeline_steps.index("tokenize")

print("Position of 'tokenize':", tokenize_position)
print("Total number of steps:", len(pipeline_steps))

try:
    del pipeline_steps[0]
except TypeError as e:
    print("Error:", e)
# Out:
# ----- Part (a) -----
# POS tags: [('language', 'NOUN'), ('processes', 'VERB'), ('human', 'ADJ'), ('text', 'NOUN'), ('quickly', 'ADV')]
# Word from second tuple: processes
# Tag from second tuple: VERB
#
# ----- Part (b) -----
# Word: language
# Tag: NOUN
# Error: 'tuple' object does not support item assignment
#
# ----- Part (c) -----
# Nouns: ['language', 'text']
#
# ----- Part (d) -----
# Pipeline: ('load_data', 'clean_text', 'tokenize', 'remove_stopwords', 'vectorize')
# Position of 'tokenize': 2
# Total number of steps: 5
# Error: 'tuple' object doesn't support item deletion

# %%
# Task 06: String Cleaning Methods


# Part (a)
print("----- Part (a) -----")

text = "   MACHINE Learning is AMAZING!!!   "

text = text.strip()
print("After strip():", text)

text = text.lower()
print("After lower():", text)

text = text.replace("!", "")
print("After replace():", text)


# Part (b)
print("\n----- Part (b) -----")

words = text.split()
print("Words:", words)

uppercase_words = [word.upper() for word in words]
print("Uppercase words:", uppercase_words)

joined_text = " | ".join(uppercase_words)
print("Joined text:", joined_text)


# Part (c)
print("\n----- Part (c) -----")

sentence = "I love Java and Java is popular"

updated_sentence = sentence.replace("Java", "Python")

print("Updated sentence:", updated_sentence)

position = updated_sentence.find("Python")

print("Starting position of first 'Python':", position)


# Part (d)
print("\n----- Part (d) -----")

def normalize(text):
    text = text.strip()
    text = text.lower()
    text = text.replace(",", "")
    text = text.replace(".", "")

    return text


text1 = "  Hello, World.  "
text2 = "  Natural Language Processing, is interesting.  "

print("Original:", text1)
print("Cleaned:", normalize(text1))

print("Original:", text2)
print("Cleaned:", normalize(text2))
# Out:
# ----- Part (a) -----
# After strip(): MACHINE Learning is AMAZING!!!
# After lower(): machine learning is amazing!!!
# After replace(): machine learning is amazing
#
# ----- Part (b) -----
# Words: ['machine', 'learning', 'is', 'amazing']
# Uppercase words: ['MACHINE', 'LEARNING', 'IS', 'AMAZING']
# Joined text: MACHINE | LEARNING | IS | AMAZING
#
# ----- Part (c) -----
# Updated sentence: I love Python and Python is popular
# Starting position of first 'Python': 7
#
# ----- Part (d) -----
# Original:   Hello, World.
# Cleaned: hello world
# Original:   Natural Language Processing, is interesting.
# Cleaned: natural language processing is interesting

# %%
# Task 07: String Validation Methods


# Part (a)
print("----- Part (a) -----")

text = "NLP is the future of AI research"

starts_with_nlp = text.startswith("NLP")
ends_with_research = text.endswith("research")
future_position = text.find("future")

print("Does the text start with 'NLP'?", starts_with_nlp)
print("Does the text end with 'research'?", ends_with_research)
print("Starting position of 'future':", future_position)


# Part (b)
print("\n----- Part (b) -----")

tokens = ["hello", "123", "world", "456abc", "python", "789", "NLP3"]

for token in tokens:
    if token.isalpha():
        print(token, "-> Alphabetic")
    elif token.isdigit():
        print(token, "-> Numeric")
    else:
        print(token, "-> Mixed")


# Part (c)
print("\n----- Part (c) -----")

words = ["running", "jumped", "NLP", "ai2025", "data", "42"]

pure_words = []
pure_numbers = []
mixed_tokens = []

for word in words:
    if word.isalpha():
        pure_words.append(word)
    elif word.isdigit():
        pure_numbers.append(word)
    else:
        mixed_tokens.append(word)

print("Pure words:", pure_words)
print("Pure numbers:", pure_numbers)
print("Mixed tokens:", mixed_tokens)


# Part (d)
print("\n----- Part (d) -----")

def validate_token(token):
    if token.isalpha():
        return "WORD"
    elif token.isdigit():
        return "NUMBER"
    else:
        return "MIXED"


tokens = ["chat", "99", "gpt4", "bert", "2024", "nlp!"]

for token in tokens:
    label = validate_token(token)
    print(token, "->", label)
# Out:
# ----- Part (a) -----
# Does the text start with 'NLP'? True
# Does the text end with 'research'? True
# Starting position of 'future': 11
#
# ----- Part (b) -----
# hello -> Alphabetic
# 123 -> Numeric
# world -> Alphabetic
# 456abc -> Mixed
# python -> Alphabetic
# 789 -> Numeric
# NLP3 -> Mixed
#
# ----- Part (c) -----
# Pure words: ['running', 'jumped', 'NLP', 'data']
# Pure numbers: ['42']
# Mixed tokens: ['ai2025']
#
# ----- Part (d) -----
# chat -> WORD
# 99 -> NUMBER
# gpt4 -> MIXED
# bert -> WORD
# 2024 -> NUMBER
# nlp! -> MIXED

# %%
# Task 08: Functions and Lambda for NLP Pipelines


# Part (a)
# Regular function
def clean(text):
    text = text.strip()
    text = text.lower()
    return text


# Equivalent lambda function
clean_lambda = lambda text: text.strip().lower()


# Test the functions
text = "  HELLO Natural Language Processing  "

print("Regular function:", clean(text))
print("Lambda function:", clean_lambda(text))


# Part (b)
# Function to tokenize the text
def tokenize(text):
    return text.split()


# Function to remove words shorter than or equal to n
def remove_short(tokens, n):
    result = []

    for word in tokens:
        if len(word) > n:
            result.append(word)

    return result


# Given sentence
sentence = "I love working with NLP tools in Python daily"

tokens = tokenize(sentence)
filtered_tokens = remove_short(tokens, 3)

print("\nTokens:", tokens)
print("After removing short words:", filtered_tokens)


# Part (c)
# Function to find the length of each word
def word_lengths(tokens):
    result = {}

    for word in tokens:
        result[word] = len(word)

    return result


tokens = ["language", "model", "ai", "processing", "deep"]

lengths = word_lengths(tokens)

print("\nWord lengths:", lengths)


# Part (d)
# Complete NLP pipeline
def nlp_pipeline(text, min_len):
    # Clean the text
    text = clean(text)

    # Tokenize the text
    tokens = tokenize(text)

    # Remove short words
    tokens = remove_short(tokens, min_len)

    # Find the length of each remaining word
    result = word_lengths(tokens)

    return result


# First sentence
sentence1 = "  Natural Language Processing is very interesting  "

# Second sentence
sentence2 = "Artificial Intelligence helps computers learn"


print("\nPipeline result for sentence 1:")
print(nlp_pipeline(sentence1, 3))

print("\nPipeline result for sentence 2:")
print(nlp_pipeline(sentence2, 3))
# Out:
# Regular function: hello natural language processing
# Lambda function: hello natural language processing
#
# Tokens: ['I', 'love', 'working', 'with', 'NLP', 'tools', 'in', 'Python', 'daily']
# After removing short words: ['love', 'working', 'with', 'tools', 'Python', 'daily']
#
# Word lengths: {'language': 8, 'model': 5, 'ai': 2, 'processing': 10, 'deep': 4}
#
# Pipeline result for sentence 1:
# {'natural': 7, 'language': 8, 'processing': 10, 'very': 4, 'interesting': 11}
#
# Pipeline result for sentence 2:
# {'artificial': 10, 'intelligence': 12, 'helps': 5, 'computers': 9, 'learn': 5}

# %%
words = ["Python", "NLP", "is", "a", "powerful", "tool", "for", "text"]

lowercase_words = list(map(lambda word: word.lower(), words))
print("Lowercase words:", lowercase_words)

word_lengths = list(map(lambda word: len(word), words))
print("Word lengths:", word_lengths)

words_long = list(filter(lambda word: len(word) > 3, words))
print("\nWords with more than 3 characters:", words_long)

words_with_t = list(filter(lambda word: "t" in word.lower(), words))
print("Words containing 't':", words_with_t)

alphabetical = sorted(words)
print("\nAlphabetically:", alphabetical)

length_ascending = sorted(words, key=len)
print("By length ascending:", length_ascending)

length_descending = sorted(words, key=len, reverse=True)
print("By length descending:", length_descending)

from collections import Counter

sentence = "nlp nlp python ai nlp python text ai nlp python text"

sentence_words = sentence.split()
freq = Counter(sentence_words)

print("\nFull Counter:", freq)
print("3 most common:", freq.most_common(3))
print("Frequency of 'python':", freq["python"])
print("Total number of words:", len(sentence_words))
print("Unique vocabulary size:", len(freq))
# Out:
# Lowercase words: ['python', 'nlp', 'is', 'a', 'powerful', 'tool', 'for', 'text']
# Word lengths: [6, 3, 2, 1, 8, 4, 3, 4]
#
# Words with more than 3 characters: ['Python', 'powerful', 'tool', 'text']
# Words containing 't': ['Python', 'tool', 'text']
#
# Alphabetically: ['NLP', 'Python', 'a', 'for', 'is', 'powerful', 'text', 'tool']
# By length ascending: ['a', 'is', 'NLP', 'for', 'tool', 'text', 'Python', 'powerful']
# By length descending: ['powerful', 'Python', 'tool', 'text', 'NLP', 'for', 'is', 'a']
#
# Full Counter: Counter({'nlp': 4, 'python': 3, 'ai': 2, 'text': 2})
# 3 most common: [('nlp', 4), ('python', 3), ('ai', 2)]
# Frequency of 'python': 3
# Total number of words: 11
# Unique vocabulary size: 4
